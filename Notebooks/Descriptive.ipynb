# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
datos=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/LONG_FORMAT.csv",sep=";")

# %%
datos
# Out:
#                ID  TIME  EDAD  SEX  LOCOMOTION  SENSORY  VITALITY  \
# 0      010003-030  2008    51  2.0         NaN      4.0         9
# 1      010004-040  2008    61  2.0         NaN     11.0        10
# 2      010013-040  2008    60  2.0         NaN     10.0        10
# 3      010038-010  2008    71  1.0         NaN     10.0        10
# 4      010038-040  2008    65  2.0         NaN     10.0         9
# ...           ...   ...   ...  ...         ...      ...       ...
# 48133  502755-010  2018    60  2.0         NaN     10.0        10
# 48134  502755-020  2018    68  1.0         NaN      7.0        10
# 48135  502758-010  2018    66  1.0         6.0     10.0         8
# 48136  502759-020  2018    69  2.0        11.0      8.0         9
# 48137  502761-010  2018    65  2.0         NaN      8.0        12
#
#        PSYCHOLOGICAL  COGNITION  PHYSICAL_ACTIVITY  SMOKE CIGARROS  TOMA  \
# 0                8.0        9.0                2.0    3.0        0   2.0
# ...

# %% [markdown]
# Relación Actividad Física - IMC

# %%
plt.scatter(datos["PHYSICAL_ACTIVITY"],datos["VITALITY"])
plt.xlabel("PHYSICAL ACTIVITY")
plt.ylabel("VITALITY")
plt.show()

# %%
plt.scatter(datos["CALC_IMC"],datos["VITALITY"])
plt.xlabel("CALC_IMC")
plt.ylabel("VITALITY")
plt.show()

# %%
datos1=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/ALL.csv",sep=",")

# %%
plt.scatter(datos1["CALC_IMC_2008"],datos["VITALITY_2008"])
plt.xlabel("CALC_IMC_2008")
plt.ylabel("VITALITY_2008")
plt.show()

# %%
plt.scatter(datos1["CIGARROS_2008"],datos["VITALITY_2008"])
plt.xlabel("CCIGARROS_2008")
plt.ylabel("VITALITY_2008")
plt.show()

# %%
datos2008=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2008.csv",sep=",")

# %%
datos2008.corr()
# Out:
# <ipython-input-16-2da984c33a19>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   datos2008.corr()
#                         EDAD_2008  SEX_2008  LOCOMOTION_2008  SENSORY_2008  \
# EDAD_2008                1.000000 -0.009890        -0.469905     -0.252875
# SEX_2008                -0.009890  1.000000        -0.031447      0.073983
# LOCOMOTION_2008         -0.469905 -0.031447         1.000000      0.207963
# SENSORY_2008            -0.252875  0.073983         0.207963      1.000000
# VITALITY_2008           -0.217426 -0.136331         0.297918      0.250466
# PSICHOLOGICAL_2008       0.066200 -0.108846         0.054764      0.178402
# COGNITION_2008          -0.437356  0.082619         0.362475      0.256854
# PHYSICAL_ACTIVITY_2008  -0.256851 -0.077328         0.309512      0.248301
# ...

# %%
matriz = datos2008.corr()
plt.figure(figsize=(10,5))
plt.matshow(matriz, cmap="bwr", vmin=-1, vmax=1, fignum=1, aspect='auto')
plt.xticks(range(len(datos2008.columns)), datos2008.columns, rotation=90)
plt.yticks(range(len(datos2008.columns)), datos2008.columns)

for i in range(len(matriz.columns)):
    for j in range(len(matriz.columns)):
        plt.text(i,j, round(matriz.iloc[i, j],2), ha="center", va="center")

plt.colorbar()
plt.show()
# Out:
# <ipython-input-30-a7ef33e37b2f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   matriz = datos2008.corr()
