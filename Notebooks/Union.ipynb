# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import pandas as pd
import numpy as np

# %%
df06=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2006.csv", sep=";")
df08=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2008.csv", sep=";")
dft=pd.merge(df06,df08)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b3db6c8e44f9> in <cell line: 1>()
# ----> 1 df06=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2006.csv", sep=";")
#       2 df08=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2008.csv", sep=";")
#       3 dft=pd.merge(df06,df08)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
df06.head
# Out:
# <bound method NDFrame.head of       HHID,PN,EDAD_2006,LOCOMOTION_2006,SENSORY_2006,VITALITY_2006,PSICHOLOGICAL_2006,COGNITION_2006,VIGOROUS_2006,MODERATE_2006,MILD_2006,LIFESTYLE_SMOKE_2006,NUM_CIGARETTESDAY_2006,LIFESTYLE_DRINK_2006,NUMDRINKSDAY_2006,LIFESTYLE_SLEEP_2006
# 0               000003,010,70,10,10,5,4,12,5,2,3,3,,1,,3
# 1                000003,020,67,10,9,4,4,12,4,5,4,3,,2,,3
# 2                  010001,010,66,,9,1,3,12,4,4,3,3,,2,,1
# 3                  010003,030,50,1,8,4,1,6,1,4,3,3,,2,,3
# 4               010004,010,66,10,8,4,3,10,2,4,3,3,,1,2,1
# ...                                                  ...
# 18464              502755,020,57,,8,1,4,6,4,4,3,3,,1,4,3
# 18465              502758,010,54,1,8,5,2,6,1,4,4,3,,2,,3
# 18466             502759,010,56,4,8,5,4,6,1,4,1,3,,1,2,2
# 18467             502759,020,57,1,9,4,4,6,2,1,5,3,,1,2,2
# 18468              502761,010,53,,10,1,4,6,1,1,2,3,,2,,2
#
# [18469 rows x 1 columns]>

# %%
df08.head
# Out:
# <bound method NDFrame.head of       HHID,PN,EDAD_2008,LOCOMOTION_2008,SENSORY_2008,VITALITY_2008,PSICHOLOGICAL_2008,COGNITION_2008,VIGOROUS_2008,MODERATE_2008,MILD_2008,LIFESTYLE_SMOKE_2008,NUM_CIGARETTESDAY_2008,LIFESTYLE_DRINK_2008,NUMDRINKSDAY_2008,LIFESTYLE_SLEEP_2008
# 0                 000003,010,72,,10,1,4,12,4,4,4,3,,1,1,
# 1                  000003,020,69,,10,1,4,12,4,4,4,3,,2,,
# 2                   010001,010,69,,7,2,3,12,1,4,3,3,,1,,
# 3                    010003,030,51,,5,3,9,6,1,1,3,3,,2,,
# 4                  010004,010,68,,6,2,3,12,2,3,3,3,,1,3,
# ...                                                  ...
# 17212                502757,010,58,,9,2,4,5,1,4,4,3,,2,,
# 17213                502758,010,56,,9,2,3,6,4,4,4,3,,1,,
# 17214              502759,010,59,,11,2,4,6,4,4,4,3,,1,3,
# 17215               502759,020,59,,9,1,3,6,1,3,4,3,,1,2,
# 17216               502761,010,54,4,9,5,3,6,1,2,3,3,,2,,
#
# [17217 rows x 1 columns]>

# %%
df06=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2006.csv", sep=",")

# %%
df06.head
# Out:
# <bound method NDFrame.head of          HHID  PN  EDAD_2006  LOCOMOTION_2006  SENSORY_2006  VITALITY_2006  \
# 0           3  10         70             10.0          10.0              5
# 1           3  20         67             10.0           9.0              4
# 2       10001  10         66              NaN           9.0              1
# 3       10003  30         50              1.0           8.0              4
# 4       10004  10         66             10.0           8.0              4
# ...       ...  ..        ...              ...           ...            ...
# 18464  502755  20         57              NaN           8.0              1
# 18465  502758  10         54              1.0           8.0              5
# 18466  502759  10         56              4.0           8.0              5
# 18467  502759  20         57              1.0           9.0              4
# 18468  502761  10         53              NaN          10.0              1
#
# ...

# %%
df06=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2006.csv", sep=",")
df08=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2008.csv", sep=",")
dft=pd.merge(df06,df08)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-114d40cab4c2> in <cell line: 1>()
# ----> 1 df06=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2006.csv", sep=",")
#       2 df08=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2008.csv", sep=",")
#       3 dft=pd.merge(df06,df08)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...

# %%
dft.head
# Out:
# <bound method NDFrame.head of          HHID  PN  EDAD_2006  LOCOMOTION_2006  SENSORY_2006  VITALITY_2006  \
# 0           3  10         70               12          10.0              5
# 1           3  20         67               12           9.0              5
# 2       10001  10         66                0           9.0              2
# 3       10003  30         50               11           8.0              3
# 4       10004  10         66               12           8.0              4
# ...       ...  ..        ...              ...           ...            ...
# 16488  502755  20         57                6           8.0              2
# 16489  502758  10         54               11           8.0              6
# 16490  502759  10         56               12           8.0              6
# 16491  502759  20         57                9           9.0              4
# 16492  502761  10         53                6          10.0              1
#
# ...

# %%
df10=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2010.csv", sep=",")
dft2=pd.merge(dft,df10)

# %%
dft2.head
# Out:
# <bound method NDFrame.head of          HHID  PN  EDAD_2006  LOCOMOTION_2006  SENSORY_2006  VITALITY_2006  \
# 0           3  10         70               12          10.0              5
# 1           3  20         67               12           9.0              5
# 2       10001  10         66                0           9.0              2
# 3       10003  30         50               11           8.0              3
# 4       10004  10         66               12           8.0              4
# ...       ...  ..        ...              ...           ...            ...
# 14457  502755  20         57                6           8.0              2
# 14458  502758  10         54               11           8.0              6
# 14459  502759  10         56               12           8.0              6
# 14460  502759  20         57                9           9.0              4
# 14461  502761  10         53                6          10.0              1
#
# ...

# %%
df12=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2012.csv", sep=",")
dft3=pd.merge(dft2,df12)

# %%
dft3.head

# %%
df14=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2014.csv", sep=",")
dft4=pd.merge(dft3,df14)

# %%
dft4.head

# %%
df16=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2016.csv", sep=",")
dft5=pd.merge(dft4,df16)

# %%
dft5.head

# %%
df18=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2018.csv", sep=",")
dft6=pd.merge(dft5,df18)

# %%
dft6.head

# %%
dft6.to_csv("/content/drive/My Drive/HRS/ESTOS/CSV/TODOS.csv",index=False)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import csv
import pandas as pd
import numpy as np

# %%
df08=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2008.csv", sep=",")
df10=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2010.csv", sep=",")
dft=pd.merge(df08,df10)

# %%
dft.head

# %%
df12=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2012.csv", sep=",")
dft3=pd.merge(dft,df12)

# %%
dft3.head

# %%
df14=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2014.csv", sep=",")
dft4=pd.merge(dft3,df14)

# %%
dft4.head

# %%
df16=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2016.csv", sep=",")
dft5=pd.merge(dft4,df16)

# %%
dft5.head

# %%
df18=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2018.csv", sep=",")
dft6=pd.merge(dft5,df18)

# %%
dft6.head

# %%
dft6.to_csv("/content/drive/My Drive/HRS/ESTOS/CSV/ALL.csv",index=False)

# %%
df08=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2008.csv", sep=",")
df12=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2012.csv", sep=",")
dft=pd.merge(df08,df12)

# %%
df16=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2016.csv", sep=",")
dft3=pd.merge(dft,df16)

# %%
dft3.head

# %%
dft3.to_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2008-2012-2016.csv",index=False)

# %%
df10=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2010.csv", sep=",")
df14=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2014.csv", sep=",")
dft2=pd.merge(df10,df14)

# %%
df18=pd.read_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2018.csv", sep=",")
dft4=pd.merge(dft2,df18)

# %%
dft4.head

# %%
dft4.to_csv("/content/drive/My Drive/HRS/ESTOS/CSV/2010-2014-2018.csv",index=False)
